# %% [markdown]
# # Principle Component Analysis (PCA)
#
# **What is PCA?**
#
# **What does it do?**
#
# **What are Principle Components and what do they represent?**
#
# **What happens as you increase the number of components used? How do you pick the best number?**
#
# **What problems does PCA resolve?**
#
# **Why/when would we use PCA?**
