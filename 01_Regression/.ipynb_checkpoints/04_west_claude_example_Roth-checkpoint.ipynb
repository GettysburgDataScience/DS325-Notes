# %% [markdown]
# # Example: West Claude University
#
# Below is a fictional survey of fictional students from the fictional West Claude University. To reiterate, this is synthetic data produced using Claude.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
wcu_df = pd.read_csv('https://raw.githubusercontent.com/GettysburgDataScience/datasets/refs/heads/main/westclaudeuniversity_survey.csv')
wcu_df.head()
# Out:
#   student_id   gpa       year    major  credits  sleep_hrs  study_hrs  \
# 0     WU0001  3.20     Senior    Other       15        NaN       17.1
# 1     WU0002  2.57     Junior  English       16        7.2        9.4
# 2     WU0003  3.17     Junior  Biology       16        6.2       21.0
# 3     WU0004  4.00     Junior    Other       16        7.7       32.6
# 4     WU0005  3.11  Sophomore  Biology       18        7.3        0.0
#
#    social_hrs  screen_hrs  mental_health_score  extracurriculars  \
# 0         0.0         3.6                  4.0                 1
# 1         7.8         2.8                  5.0                 2
# 2         4.4         5.6                  4.0                 0
# 3         7.4         5.2                  6.0                 2
# 4         2.7         1.2                  8.0                 1
#
#    extracurricular_hrs  has_minor  part_time_job  commuter  first_gen
# 0                  3.8          0              0         0          0
# 1                  7.3          1              0         0          0
# 2                  0.0          0              0         0          0
# 3                  7.3          0              0         0          0
# 4                  2.0          0              0         1          0
